# %% [markdown]
# ## Numerical Solution for the Infinite 1D Square Well - Python and the Shooting Method
# <a href="https://www.youtube.com/watch?v=ZSRDR5y3hwA" target="_blank">link to the lesson</a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4,5],[5,7,9,4,2])
